# %% [markdown]
# <a href="https://colab.research.google.com/github/Chae-sang-jun/2024-2_Ajou_Softcon_Self_Research_1/blob/main/Data_Multi_Augmentation_Softcon_%EC%A0%9C%EC%B6%9C%EC%9A%A9_202020679_%EC%B1%84%EC%83%81%EC%A4%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Import necessary libraries
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')

# !pip install gensim matplotlib seaborn tensorflow pandas tqdm

import random
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GlobalMaxPooling1D, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import wordnet
import re

# Helper functions for text preprocessing
def clean_text(text):
    text = re.sub(r'\W', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = text.lower()
    return text

# Augmentation functions
def synonym_replacement(text, n=1):
    words = text.split()
    new_words = words.copy()
    random_word_list = list(set([word for word in words if wordnet.synsets(word)]))
    random.shuffle(random_word_list)
    for random_word in random_word_list[:n]:
        synonym = wordnet.synsets(random_word)[0].lemmas()[0].name()
        new_words = [synonym if word == random_word else word for word in new_words]
    return ' '.join(new_words)

def add_punctuation(text, punc_num=1):
    puncs = ['.', ',', '!', '?']
    words = text.split()
    for _ in range(punc_num):
        idx = random.randint(0, len(words) - 1)
        words.insert(idx, random.choice(puncs))
    return ' '.join(words)

def random_insertion(text, n=1):
    words = text.split()
    for _ in range(n):
        synonym = synonym_replacement(random.choice(words))
        insert_position = random.randint(0, len(words) - 1)
        words.insert(insert_position, synonym)
    return ' '.join(words)

# Multi-Augmentation with Random Insertion
def multi_augmentation(text, num_augments=3):
    augmented_texts = []
    for _ in range(num_augments):
        aug_text = add_punctuation(text)
        aug_text = random_insertion(aug_text)
        augmented_texts.append(aug_text)
    return augmented_texts

# EDA Function (Synonym Replacement)
def eda(text, n=1):
    return synonym_replacement(text, n=n)

# Load and clean data
def load_and_clean_data(filepath):
    data = pd.read_csv(filepath)
    data = data[['review', 'sentiment']]
    data['review'] = data['review'].apply(clean_text)
    data['label'] = data['sentiment'].apply(lambda x: 1 if x == 'positive' else 0)
    return data[['review', 'label']]

# Data augmentation function
def augment_data(data, augmentation_function, num_augments):
    augmented_texts = []
    for text in data['review'].tolist()[:num_augments]:
        if augmentation_function == eda:
            augmented_texts.append(augmentation_function(text))
        else:
            augmented_texts.extend(augmentation_function(text, num_augments=1))
    return pd.DataFrame({'review': augmented_texts, 'label': data['label'].values[:len(augmented_texts)]})

# Plain augmentation function (scaling original data without modifications)
def plain_augmentation(data, num_augments):
    return data.sample(n=num_augments, replace=True, random_state=42)

# Text preprocessing function
def preprocess_text(data, tokenizer, max_len):
    sequences = tokenizer.texts_to_sequences(data['review'].tolist())
    return pad_sequences(sequences, maxlen=max_len)

# Define RNN Model
def create_rnn_model(input_dim, output_dim, max_len):
    model = Sequential([
        Embedding(input_dim, 128, input_length=max_len),
        LSTM(64, return_sequences=True),
        GlobalMaxPooling1D(),
        Dense(64, activation='relu'),
        Dense(output_dim, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Training and evaluation function
def train_and_evaluate_model(train_data, val_data, model, tokenizer, max_len):
    X_train = preprocess_text(train_data, tokenizer, max_len)
    y_train = train_data['label'].values
    X_val = preprocess_text(val_data, tokenizer, max_len)
    y_val = val_data['label'].values

    model.fit(X_train, y_train, epochs=3, batch_size=32, validation_data=(X_val, y_val))
    y_pred = model.predict(X_val).argmax(axis=1)
    accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred)
    return accuracy, f1, precision, recall

# Main function for experiments
if __name__ == "__main__":
    filepath = '/content/drive/MyDrive/IMDB Dataset.csv'
    data_proportions = [0.2, 0.4, 0.6, 0.8]
    methods = ['Plain', 'EDA', 'AEDA', 'Multi-Augmentation']
    metrics_dict = {method: {} for method in methods}
    train_data = load_and_clean_data(filepath)

    # Set tokenizer and padding length
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(train_data['review'].tolist())
    max_len = 128

    # Sample and augment data
    for proportion in tqdm(data_proportions, desc="Data Proportion Levels"):
        sample_size = int(len(train_data) * proportion)
        for method in methods:
            if method == 'Plain':
                sampled_data = plain_augmentation(train_data, num_augments=sample_size)
            else:
                augmentation_function = multi_augmentation if method == 'Multi-Augmentation' else eda
                augmented_samples = augment_data(
                    train_data, augmentation_function, num_augments=sample_size - len(train_data)
                )
                sampled_data = pd.concat([train_data, augmented_samples]).sample(
                    frac=1, random_state=42
                ).reset_index(drop=True)

            train_set, val_set = train_test_split(sampled_data, test_size=0.2, random_state=42)

            # RNN evaluation
            rnn_model = create_rnn_model(len(tokenizer.word_index) + 1, 2, max_len)
            rnn_accuracy, rnn_f1, rnn_precision, rnn_recall = train_and_evaluate_model(
                train_set, val_set, rnn_model, tokenizer, max_len
            )
            metrics_dict[method][proportion] = {
                'RNN Accuracy': rnn_accuracy,
                'RNN F1': rnn_f1,
                'RNN Precision': rnn_precision,
                'RNN Recall': rnn_recall,
            }

    # Save numeric results separately
    numeric_results = pd.DataFrame(metrics_dict).T
    numeric_results.to_csv('/content/drive/MyDrive/accuracy_metrics.csv', index=False)

    # Visualization: Line plots
    results_df = []
    for method in methods:
        for proportion, metrics in metrics_dict[method].items():
            results_df.append({
                'Method': method,
                'Proportion': proportion * 100,
                'RNN Accuracy': metrics['RNN Accuracy']
            })

    # Convert to DataFrame for visualization
    results_df = pd.DataFrame(results_df)

    # Line plot for Accuracy
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=results_df, x='Proportion', y='RNN Accuracy', hue='Method', marker='o')
    plt.title('RNN Accuracy across Data Proportions')
    plt.xlabel('Data Proportion (%)')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend()
    plt.show()

    # Boxplot for Methods
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=results_df, x='Method', y='RNN Accuracy')
    plt.title('RNN Accuracy Distribution by Method')
    plt.xlabel('Method')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Data Proportion Levels:   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.6445 - loss: 0.6040 - val_accuracy: 0.8455 - val_loss: 0.3494
# Epoch 2/3
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9287 - loss: 0.1953 - val_accuracy: 0.8195 - val_loss: 0.3963
# Epoch 3/3
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9792 - loss: 0.0650 - val_accuracy: 0.8565 - val_loss: 0.4101
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.7904 - loss: 0.4275 - val_accuracy: 0.9041 - val_loss: 0.2400
# Epoch 2/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9526 - loss: 0.1323 - val_accuracy: 0.9112 - val_loss: 0.2336
# Epoch 3/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9869 - loss: 0.0429 - val_accuracy: 0.9053 - val_loss: 0.3140
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.7874 - loss: 0.4195 - val_accuracy: 0.8899 - val_loss: 0.2613
# Epoch 2/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9497 - loss: 0.1395 - val_accuracy: 0.9100 - val_loss: 0.2411
# Epoch 3/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9834 - loss: 0.0519 - val_accuracy: 0.9053 - val_loss: 0.3260
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.7870 - loss: 0.4258 - val_accuracy: 0.9035 - val_loss: 0.2423
# Epoch 2/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9505 - loss: 0.1369 - val_accuracy: 0.9057 - val_loss: 0.2346
# Epoch 3/3
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9843 - loss: 0.0493 - val_accuracy: 0.9069 - val_loss: 0.3068
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Data Proportion Levels:  25%|██▌       | 1/4 [05:01<15:04, 301.50s/it]/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7184 - loss: 0.5307 - val_accuracy: 0.8683 - val_loss: 0.3053
# Epoch 2/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.9436 - loss: 0.1535 - val_accuracy: 0.8923 - val_loss: 0.2738
# Epoch 3/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.9865 - loss: 0.0467 - val_accuracy: 0.8910 - val_loss: 0.3283
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.8007 - loss: 0.4011 - val_accuracy: 0.9099 - val_loss: 0.2264
# Epoch 2/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9582 - loss: 0.1195 - val_accuracy: 0.9188 - val_loss: 0.2193
# Epoch 3/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9873 - loss: 0.0413 - val_accuracy: 0.9234 - val_loss: 0.2633
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.8026 - loss: 0.4003 - val_accuracy: 0.9130 - val_loss: 0.2240
# Epoch 2/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9586 - loss: 0.1177 - val_accuracy: 0.9287 - val_loss: 0.1978
# Epoch 3/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9876 - loss: 0.0394 - val_accuracy: 0.9287 - val_loss: 0.2405
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.7964 - loss: 0.4070 - val_accuracy: 0.9025 - val_loss: 0.2431
# Epoch 2/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9559 - loss: 0.1239 - val_accuracy: 0.9255 - val_loss: 0.1971
# Epoch 3/3
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9872 - loss: 0.0418 - val_accuracy: 0.9281 - val_loss: 0.2378
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Data Proportion Levels:  50%|█████     | 2/4 [11:54<12:14, 367.30s/it]/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.7428 - loss: 0.4869 - val_accuracy: 0.8898 - val_loss: 0.2678
# Epoch 2/3
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9503 - loss: 0.1368 - val_accuracy: 0.8995 - val_loss: 0.2767
# Epoch 3/3
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9869 - loss: 0.0403 - val_accuracy: 0.9047 - val_loss: 0.3077
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 14ms/step - accuracy: 0.8078 - loss: 0.3896 - val_accuracy: 0.9245 - val_loss: 0.2008
# Epoch 2/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - accuracy: 0.9621 - loss: 0.1071 - val_accuracy: 0.9402 - val_loss: 0.1680
# Epoch 3/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - accuracy: 0.9910 - loss: 0.0311 - val_accuracy: 0.9447 - val_loss: 0.2045
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 15ms/step - accuracy: 0.8018 - loss: 0.3950 - val_accuracy: 0.9170 - val_loss: 0.2072
# Epoch 2/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.9624 - loss: 0.1088 - val_accuracy: 0.9409 - val_loss: 0.1748
# Epoch 3/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.9907 - loss: 0.0324 - val_accuracy: 0.9438 - val_loss: 0.1917
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 14ms/step - accuracy: 0.8092 - loss: 0.3888 - val_accuracy: 0.9223 - val_loss: 0.2084
# Epoch 2/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - accuracy: 0.9608 - loss: 0.1118 - val_accuracy: 0.9424 - val_loss: 0.1686
# Epoch 3/3
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 29s 14ms/step - accuracy: 0.9886 - loss: 0.0370 - val_accuracy: 0.9483 - val_loss: 0.1915
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Data Proportion Levels:  75%|███████▌  | 3/4 [20:43<07:20, 440.87s/it]/usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.7768 - loss: 0.4404 - val_accuracy: 0.8991 - val_loss: 0.2549
# Epoch 2/3
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9593 - loss: 0.1156 - val_accuracy: 0.9202 - val_loss: 0.2121
# Epoch 3/3
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9875 - loss: 0.0411 - val_accuracy: 0.9227 - val_loss: 0.2569
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 35s 14ms/step - accuracy: 0.8138 - loss: 0.3834 - val_accuracy: 0.9307 - val_loss: 0.1885
# Epoch 2/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.9656 - loss: 0.0979 - val_accuracy: 0.9537 - val_loss: 0.1381
# Epoch 3/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.9912 - loss: 0.0285 - val_accuracy: 0.9561 - val_loss: 0.1543
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 35s 14ms/step - accuracy: 0.8206 - loss: 0.3756 - val_accuracy: 0.9207 - val_loss: 0.2033
# Epoch 2/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.9669 - loss: 0.0965 - val_accuracy: 0.9524 - val_loss: 0.1388
# Epoch 3/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.9915 - loss: 0.0283 - val_accuracy: 0.9581 - val_loss: 0.1607
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - accuracy: 0.8167 - loss: 0.3761 - val_accuracy: 0.9368 - val_loss: 0.1751
# Epoch 2/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.9647 - loss: 0.0994 - val_accuracy: 0.9487 - val_loss: 0.1518
# Epoch 3/3
# 2250/2250 ━━━━━━━━━━━━━━━━━━━━ 32s 14ms/step - accuracy: 0.9911 - loss: 0.0281 - val_accuracy: 0.9590 - val_loss: 0.1465
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Data Proportion Levels: 100%|██████████| 4/4 [31:15<00:00, 468.94s/it]
